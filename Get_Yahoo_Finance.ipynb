# %%
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as pdr
import datetime
def get(tickers, startdate, enddate):
    def data(ticker):
        return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
    datas = map (data, tickers)
    return(pd.concat(datas, keys=tickers, names=['Ticker', 'Date']))

#---------------------NSE500-------------------------------------
#1tickers = ['3MINDIA.NS','8KMILES.NS','ABB.NS','ACC.NS']
#2tickers = ['AIAENG.NS','APLAPOLLO.NS','AUBANK.NS','AARTIIND.NS']
#3tickers = ['ABAN.NS','ADANIENT.NS','ADANIPORTS.NS','ADANIPOWER.NS']
#4tickers = ['ADANITRANS.NS','ABFRL.NS','ADVENZYMES.NS','AEGISCHEM.NS']
#5tickers = ['AHLUCONT.NS','AJANTPHARM.NS','AKZOINDIA.NS','APLLTD.NS']
#6tickers = ['ALKEM.NS','ALBK.NS','ALLCARGO.NS','AMARAJABAT.NS']
#7tickers = ['AMBUJACEM.NS','ANDHRABANK.NS','APARINDS.NS','APOLLOHOSP.NS']
#8tickers = ['APOLLOTYRE.NS','ARVIND.NS','ASHOKLEY.NS','ASHOKA.NS']
#9tickers = ['ASIANPAINT.NS','ASTRAZEN.NS','ASTRAL.NS','ATUL.NS']
#10tickers = ['AUROPHARMA.NS','AVANTIFEED.NS','DMART.NS','AXISBANK.NS']
#11tickers = ['BASF.NS','BEML.NS','BFUTILITIE.NS','BGRENERGY.NS']
#12tickers = ['BSE.NS','BAJAJCORP.NS','BAJAJELEC.NS']#BAJAJ-AUTO.NS errors out
#13tickers = ['BAJFINANCE.NS','BAJAJFINSV.NS','BAJAJHIND.NS','BAJAJHLDNG.NS']
#14tickers = ['BALKRISIND.NS','BALLARPUR.NS','BALMLAWRIE.NS','BALRAMCHIN.NS']
#15tickers = ['BANKBARODA.NS','BANKINDIA.NS','BATAINDIA.NS','BERGEPAINT.NS']
#16tickers = ['BEL.NS','BHARATFIN.NS','BHARATFORG.NS','BHEL.NS']
#17tickers = ['BPCL.NS','BHARTIARTL.NS','INFRATEL.NS','BHUSANSTL.NS']
#18tickers = ['BIOCON.NS','BIRLACORPN.NS','BLISSGVS.NS','BLUEDART.NS']
#19tickers = ['BLUESTARCO.NS','BBTC.NS','BOMDYEING.NS','BRFL.NS']
#20tickers = ['BOSCHLTD.NS','BRIGADE.NS','BRITANNIA.NS','CARERATING.NS']
#21tickers = ['CCL.NS','CESC.NS','CGPOWER.NS','CRISIL.NS']
#22tickers = ['CADILAHC.NS','CANFINHOME.NS','CANBK.NS','CAPF.NS']
#23tickers = ['CAPLIPOINT.NS','CARBORUNIV.NS','CASTROLIND.NS','CEATLTD.NS']
#24tickers = ['CENTRALBK.NS','CENTURYPLY.NS','CENTURYTEX.NS','CERA.NS']
#25tickers = ['CHAMBLFERT.NS','CHENNPETRO.NS','CHOLAFIN.NS','CIPLA.NS']
#26tickers = ['CUB.NS','COALINDIA.NS','COFFEEDAY.NS','COLPAL.NS']
#27tickers = ['CONCOR.NS','COROMANDEL.NS','CORPBANK.NS','COX&KINGS.NS']
#28tickers = ['CROMPTON.NS','CUMMINSIND.NS','CYIENT.NS','DBREALTY.NS']
#29tickers = ['DBCORP.NS','DCBBANK.NS','DCMSHRIRAM.NS','DLF.NS']
#30tickers = ['DABUR.NS','DALMIABHA.NS','DEEPAKFERT.NS','DELTACORP.NS']
#31tickers = ['DEN.NS','DENABANK.NS','DHFL.NS','DHANUKA.NS']
#32tickers = ['DBL.NS','DISHTV.NS','DIVISLAB.NS','LALPATHLAB.NS']
#33tickers = ['DRREDDY.NS','DREDGECORP.NS','EIDPARRY.NS','EIHOTEL.NS']
#34tickers = ['EDELWEISS.NS','EICHERMOT.NS','EMAMILTD.NS','ENDURANCE.NS']
#35tickers = ['ENGINERSIN.NS','EQUITAS.NS','EROSMEDIA.NS','ESCORTS.NS']
#36tickers = ['ESSELPACK.NS','EVEREADY.NS','EXIDEIND.NS','FEDERALBNK.NS']
#37tickers = ['FINCABLES.NS','FINPIPE.NS','FSL.NS','FORTIS.NS']
#38tickers = ['FCONSUMER.NS','FLFL.NS','GAIL.NS','GEPIL.NS']
#39tickers = ['GET&D.NS','GHCL.NS','GMRINFRA.NS','GVKPIL.NS']
#40tickers = ['GDL.NS','GATI.NS','GILLETTE.NS','GSKCONS.NS']
#41tickers = ['GLAXO.NS','GLENMARK.NS','GODFRYPHLP.NS','GODREJCP.NS']
#42tickers = ['GODREJIND.NS','GODREJPROP.NS','GRANULES.NS','GESHIP.NS']
#43tickers = ['GREAVESCOT.NS','GREENPLY.NS','GRUH.NS','GUJALKALI.NS']
#44tickers = ['GUJFLUORO.NS','GUJGASLTD.NS','GMDCLTD.NS','GNFC.NS']
#45tickers = ['GPPL.NS','GSFC.NS','GSPL.NS','GULFOILLUB.NS']
#46tickers = ['HCLTECH.NS','HDFCBANK.NS','HSIL.NS']#'HCL-INSYS.NS',
#47tickers = ['HTMEDIA.NS','HATHWAY.NS','HAVELLS.NS','HEIDELBERG.NS']
#48tickers = ['HERITGFOOD.NS','HEROMOTOCO.NS','HEXAWARE.NS','HFCL.NS']
#49tickers = ['HIMATSEIDE.NS','HINDALCO.NS','HCC.NS','HINDCOPPER.NS']
#50tickers = ['HINDPETRO.NS','HINDUNILVR.NS','HINDZINC.NS','HUDCO.NS']
#51tickers = ['HDFC.NS','HDIL.NS','ITC.NS','ICICIBANK.NS']
#52tickers = ['ICICIPRULI.NS','ICRA.NS','IDBI.NS','IDFCBANK.NS']
#53tickers = ['IDFC.NS','IFBIND.NS','IFCI.NS','IL&FSTRANS.NS']
#54tickers = ['IRB.NS','ITDCEM.NS','ITI.NS','IDEA.NS']
#55tickers = ['IGARASHI.NS','INDIACEM.NS','ITDC.NS','IBULHSGFIN.NS']
#56tickers = ['IBREALEST.NS','IBVENTURES.NS','INDIANB.NS','INDHOTEL.NS']
#57tickers = ['IOC.NS','IOB.NS','ICIL.NS','INDOCO.NS']
#58tickers = ['IGL.NS','INDUSINDBK.NS','INFIBEAM.NS','NAUKRI.NS']
#59tickers = ['INFY.NS','INGERRAND.NS','INOXLEISUR.NS','INOXWIND.NS']
#60tickers = ['INTELLECT.NS','INDIGO.NS','IPCALAB.NS','JBCHEPHARM.NS']
#61tickers = ['JKCEMENT.NS','JKIL.NS','JBFIND.NS','JKLAKSHMI.NS']
#62tickers = ['JKTYRE.NS','JMFINANCIL.NS','JSWENERGY.NS','JSWSTEEL.NS']
#63tickers = ['JAGRAN.NS','JAICORPLTD.NS','JISLJALEQS.NS','JPASSOCIAT.NS']
#64tickers = ['JPPOWER.NS','J&KBANK.NS','JETAIRWAYS.NS','JINDALPOLY.NS']
#65tickers = ['JINDALSAW.NS','JSLHISAR.NS','JSL.NS','JINDALSTEL.NS']
#66tickers = ['JCHAC.NS','JUBLFOOD.NS','JUBILANT.NS','JUSTDIAL.NS']
#67tickers = ['JYOTHYLAB.NS','KPRMILL.NS','KPIT.NS','KRBL.NS']
#68tickers = ['KAJARIACER.NS','KALPATPOWR.NS','KANSAINER.NS','KTKBANK.NS']
#69tickers = ['KARURVYSYA.NS','KSCL.NS','KEC.NS','KESORAMIND.NS']
#70tickers = ['KITEX.NS','KOLTEPATIL.NS','KOTAKBANK.NS','KWALITY.NS']
#71tickers = ['L&TFH.NS','LTTS.NS','LICHSGFIN.NS','LAXMIMACH.NS']
#72tickers = ['LAKSHVILAS.NS','LTI.NS','LT.NS','LAURUSLABS.NS']
#73tickers = ['LINDEINDIA.NS','LUPIN.NS','MMTC.NS','MOIL.NS']
#74tickers = ['MRF.NS','MAGMA.NS','MGL.NS','MTNL.NS']
#75tickers = ['M&MFIN.NS','M&M.NS','MAHINDCIE.NS','MHRIL.NS']
#76tickers = ['MANAPPURAM.NS','MRPL.NS','MANPASAND.NS','MARICO.NS']
#77tickers = ['MARKSANS.NS','MARUTI.NS','MFSL.NS','MAXINDIA.NS']
#78tickers = ['MCLEODRUSS.NS','MERCK.NS','MINDTREE.NS','MINDACORP.NS']
#79tickers = ['MINDAIND.NS','MONSANTO.NS','MOTHERSUMI.NS','MOTILALOFS.NS']
#80tickers = ['MPHASIS.NS','MUTHOOTFIN.NS','NATCOPHARM.NS','NBCC.NS']
#81tickers = ['NCC.NS','NHPC.NS','NIITTECH.NS','NLCINDIA.NS']
#82tickers = ['NMDC.NS','NTPC.NS','NH.NS','NATIONALUM.NS']
#83tickers = ['NFL.NS','NBVENTURES.NS','NAVINFLUOR.NS','NAVKARCORP.NS']
#84tickers = ['NAVNETEDUL.NS','NETWORK18.NS','NILKAMAL.NS','OBEROIRLTY.NS']
#85tickers = ['ONGC.NS','OIL.NS','OMAXE.NS','OFSS.NS']
#86tickers = ['ORIENTCEM.NS','ORIENTBANK.NS','PCJEWELLER.NS','PIIND.NS']
#87tickers = ['PNBHOUSING.NS','PNCINFRA.NS','PFS.NS','PTC.NS']
#88tickers = ['PVR.NS','PAGEIND.NS','PARAGMILK.NS','PERSISTENT.NS']
#89tickers = ['PETRONET.NS','PFIZER.NS','PHOENIXLTD.NS','PIDILITIND.NS']
#90tickers = ['PEL.NS','POLARIS.NS','PFC.NS','POWERGRID.NS']
#91tickers = ['PRAJIND.NS','PRESTIGE.NS','PRISMCEM.NS','PGHH.NS']
#92tickers = ['PNB.NS','QUESS.NS','RBLBANK.NS','RADICO.NS']
#93tickers = ['RAIN.NS','RAJESHEXPO.NS','RALLIS.NS','RAMCOSYS.NS']
#94tickers = ['RKFORGE.NS','RCF.NS','RTNPOWER.NS','RAYMOND.NS']
#95tickers = ['REDINGTON.NS','RELAXO.NS','RCOM.NS','RELIANCE.NS']
#96tickers = ['RELINFRA.NS','RNAVAL.NS','RPOWER.NS','RELIGARE.NS']
#97tickers = ['REPCOHOME.NS','RUPA.NS','RECLTD.NS','SHK.NS']
#98tickers = ['SJVN.NS','SKFINDIA.NS','SMLISUZU.NS','SREINFRA.NS']
#99tickers = ['SRF.NS','SADBHAV.NS','SANOFI.NS','SCHAEFFLER.NS']
#100tickers = ['SCHNEIDER.NS','SHARDACROP.NS','SFL.NS','SHILPAMED.NS']
#101tickers = ['SCI.NS','SHOPERSTOP.NS','SHREECEM.NS','RENUKA.NS']
#102tickers = ['SHRIRAMCIT.NS','SRTRANSFIN.NS','SIEMENS.NS','SNOWMAN.NS']
#103tickers = ['SOBHA.NS','SOLARINDS.NS','SOMANYCERA.NS','SONATSOFTW.NS']
#104tickers = ['SOUTHBANK.NS','STARCEMENT.NS','SBIN.NS','SAIL.NS']
#105tickers = ['STRTECH.NS','STAR.NS','SUDARSCHEM.NS','SPARC.NS']
#106tickers = ['SUNPHARMA.NS','SUNTV.NS','SUNDRMFAST.NS','SUNTECK.NS']
#107tickers = ['SUPRAJIT.NS','SUPREMEIND.NS','SUPPETRO.NS','SUVEN.NS']
#108tickers = ['SUZLON.NS','SWANENERGY.NS','SYMPHONY.NS','SYNDIBANK.NS']
#109tickers = ['SYNGENE.NS','TTKPRESTIG.NS','TVTODAY.NS','TV18BRDCST.NS']
#110tickers = ['TVSMOTOR.NS','TVSSRICHAK.NS','TAKE.NS','TNPL.NS']
#111tickers = ['TATACHEM.NS','TATACOFFEE.NS','TATACOMM.NS','TCS.NS']
#112tickers = ['TATAELXSI.NS','TATAGLOBAL.NS','TATAINVEST.NS','TATAMTRDVR.NS']
#113tickers = ['TATAMOTORS.NS','TATAPOWER.NS','TATASPONGE.NS','TATASTEEL.NS']
#114tickers = ['TECHM.NS','TECHNO.NS','TEXRAIL.NS','RAMCOCEM.NS']
#115tickers = ['THERMAX.NS','THOMASCOOK.NS','THYROCARE.NS','TIMETECHNO.NS']
#116tickers = ['TIMKEN.NS','TITAN.NS','TORNTPHARM.NS','TORNTPOWER.NS']
#117tickers = ['TRENT.NS','TRIDENT.NS','UCOBANK.NS','UFLEX.NS']
#118tickers = ['UPL.NS','UJJIVAN.NS','ULTRACEMCO.NS','UNICHEMLAB.NS']
#119tickers = ['UNIONBANK.NS','UNITECH.NS','UNITEDBNK.NS','UBL.NS']
#120tickers = ['VGUARD.NS','VIPIND.NS','VRLLOG.NS']#'MCDOWELL-N.NS'
#121tickers = ['WABAG.NS','VAKRANGEE.NS','VTL.NS','VBL.NS']
#122tickers = ['VEDL.NS','VESUVIUS.NS','VIDEOIND.NS','VIJAYABANK.NS']
#123tickers = ['VINATIORGA.NS','VOLTAS.NS','WABCOINDIA.NS','WELCORP.NS']
#124tickers = ['WELSPUNIND.NS','WHIRLPOOL.NS','WIPRO.NS','WOCKPHARMA.NS']
#125tickers = ['YESBANK.NS','ZEEL.NS','ZEELEARN.NS','ZENSARTECH.NS']
#126tickers = ['ECLERX.NS']
all_data = get(tickers, datetime.datetime(2016, 12, 5), datetime.datetime(2018, 3, 5))
# Isolate the `Adj Close` values and transform the DataFrame
daily_close_px = all_data[['Adj Close']].reset_index().pivot('Date','Ticker','Adj Close')
daily_close_px.to_csv('fetched_data.csv') # export to csv
print('*****DONE*****')
# Out:
# *****DONE*****
